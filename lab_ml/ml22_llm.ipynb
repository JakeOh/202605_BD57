# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202605_BD57/blob/main/lab_ml/ml22_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXAONE 모델을 사용한 질문-답변 시스템

# %% [markdown]
# # Imports

# %%
# !pip install transformers==5.1.0
# Out:
# Collecting transformers==5.1.0
#   Downloading transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (1.29.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==5.1.0)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer-slim (from transformers==5.1.0)
#   Downloading typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.13/dist-packages (from transformers==5.1.0) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (4.16.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.13/dist-packages (from typer-slim->transformers==5.1.0) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.1.0) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.24.0->typer-slim->transformers==5.1.0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.24.0->typer-slim->transformers==5.1.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.24.0->typer-slim->transformers==5.1.0) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer>=0.24.0->typer-slim->transformers==5.1.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer>=0.24.0->typer-slim->transformers==5.1.0) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.24.0->typer-slim->transformers==5.1.0) (0.1.2)
# Downloading transformers-5.1.0-py3-none-any.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 75.6 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 92.2 MB/s eta 0:00:00
# Downloading typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Installing collected packages: typer-slim, tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
# Successfully installed tokenizers-0.22.2 transformers-5.1.0 typer-slim-0.24.0

# %%
import numpy as np
import scipy
import transformers

# %%
transformers.__version__  #> 5.16.1
# Out:
# '5.1.0'

# %%
# transformers 모듈의 함수를 사용할 때 progress bar를 출력창에 보여주는 것을 비활성.
transformers.utils.logging.disable_progress_bar()

# %% [markdown]
# # EXAONE-3.5 모델

# %%
pipe = transformers.pipeline(
    task='text-generation',
    model='LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct',
    device=0,  # GPU 사용
    trust_remote_code=True
)

# %%
# 메시지 템플릿: 'role'과 'content'를 키로 갖는 dict들의 list.
# role: 역할(system, user, assistant)
# content: 내용
messages = [
    {
        'role': 'system',
        'content': '너는 사용자의 질문에 정확한 답변을 해주는 친절한 AI 비서야.'
    },
    {
        'role': 'user',
        'content': '2026 아시안게임 야구 우승팀은 어느 나라야?',
    }
]

# %%
result = pipe(messages, max_new_tokens=200)
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(result)
# Out:
# [{'generated_text': [{'role': 'system', 'content': '너는 사용자의 질문에 정확한 답변을 해주는 친절한 AI 비서야.'}, {'role': 'user', 'content': '2026 아시안게임 야구 우승팀은 어느 나라야?'}, {'role': 'assistant', 'content': '2026년 아시안 게임의 야구 경기 일정과 최종 우승팀은 아직 공식적으로 발표되지 않았습니다. 아시안 게임 야구 대회는 주로 해당 연도에 열리는 경기 결과에 따라 우승팀이 결정됩니다. 정확한 정보를 위해서는 다음과 같은 방법을 추천드립니다:\n\n1. **공식 아시안 게임 웹사이트**: 가장 신뢰할 수 있는 정보는 공식 아시안 게임 웹사이트나 관련 뉴스 출처에서 확인하실 수 있습니다.\n2. **스포츠 뉴스 사이트**: ESPN 아시아나 다른 지역별 스포츠 뉴스 사이트에서도 최신 업데이트를 확인할 수 있습니다.\n3. **대한야구협회**: 한국의 야구 관련 공식 기관인 대한야구협회 웹사이트도 유용한 정보를 제공할 수 있습니다.\n\n이러한 출처들을 통해 최신 정보를 얻으실 수 있을 것입니다. 만약 특정 국가의 기대나 과거 성적을 바탕으로 추측하고 계신다면, 그 나라의'}]}]
