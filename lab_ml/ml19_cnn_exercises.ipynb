# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202605_BD57/blob/main/lab_ml/ml19_cnn_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 유명한 CNN 모델들:
#
# *   LeNet-5
# *   AlexNet
# *   GoogLeNet
# *   VGGNet
# *   ResNet
# *   Xception
# *   SENet

# %% [markdown]
# # Imports

# %%
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

import keras
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
keras.__version__
# Out:
# '3.13.2'

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # CNN 연습 1

# %% [markdown]
# *   Keras 패키지의 Fashion MNIST 데이터 셋
#     *   훈련 셋과 테스트 셋의 데이터는 0. ~ 1. 스케일로 스케일링
# *   CNN 모델 구조
#     *   Conv2D(filters=64, kernel_size=7)
#     *   MaxPool2D
#     *   Conv2D(filters=128, kernel_size=3)
#     *   Conv2D(filters=128, kernel_size=3)
#     *   MaxPool2D
#     *   Conv2D(filters=256, kernel_size=3)
#     *   Conv2D(filters=256, kernel_size=3)
#     *   MaxPool2D
#     *   Flatten
#     *   Dense(units=128)
#     *   Dropout(rate=0.5)
#     *   Dense(units=64)
#     *   Dropout(rate=0.5)
#     *   Dense - 출력층
#     *   출력층을 제외한 층(Conv2D, Dense)들의 활성화 함수는 ReLU
#     *   합성곱 층의 `padding` 방식은 'same' 방식.
#     *   합성곱 층의 커널 초기화 함수(`kernel_initializer`)는 'he_normal'
# *   모델 컴파일 시 `optimizer`는 Nadam으로 설정.
# *   ModelCheckpoint, EarlyStopping 콜백을 사용해서 모델 훈련을 조기 종료하고, 최적의 모델은 best_cnn1.keras 파일에 저장.
# *   각 에포크에서의 손실 함수를 시각화.
# *   모델 성능 평가

# %% [markdown]
# ## Fashion MNIST 데이터셋 준비

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ### 데이터셋 시각화

# %%
def plot_mnist_image(arr, ncols=10):
    # arr: (n_samples, height, width) 모양의 배열.
    n_samples = len(arr)
    nrows = int(np.ceil(n_samples / ncols))
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols, nrows))
    for i in range(nrows):
        for j in range(ncols):
            idx = i * ncols + j
            if nrows == 1 or ncols == 1:
                if idx < n_samples:
                    ax[idx].imshow(arr[idx], cmap=plt.cm.binary)
                ax[idx].axis('off')
            else:
                if idx < n_samples:
                    ax[i, j].imshow(arr[idx], cmap=plt.cm.binary)
                ax[i, j].axis('off')
    plt.show()

# %%
plot_mnist_image(x_train[:50])

# %%
# 훈련 셋과 테스트 셋을 (n_samples, height, width, channels) 모양으로 변환하고 0.0 ~ 1.0 스케일로 바꿈.
x_train_scaled = x_train.reshape((-1, 28, 28, 1)) / 255.0
x_test_scaled = x_test.reshape((-1, 28, 28, 1)) / 255.0

# %% [markdown]
# ## CNN 모델 생성

# %%
keras.utils.set_random_seed(42)

# %%
cnn_1 = keras.Sequential(layers=[
    keras.Input(shape=(28, 28, 1)),
    keras.layers.Conv2D(filters=64, kernel_size=7, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D(filters=128, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.Conv2D(filters=128, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu', kernel_initializer='he_normal'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=10, activation='softmax')
])

# %%
cnn_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 64)     │         3,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,413,834 (5.39 MB)
#  Trainable params: 1,413,834 (5.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(model=cnn_1, dpi=64, show_shapes=True)

# %% [markdown]
# ## CNN 모델 훈련

# %%
cnn_1.compile(optimizer=keras.optimizers.Nadam(),
              loss=keras.losses.sparse_categorical_crossentropy,
              metrics=[keras.metrics.sparse_categorical_accuracy])

# %%
dir = '/content/drive/MyDrive/Colab Notebooks/lab_ml'
file_name = 'best_cnn1'
suffix = datetime.now().strftime('%Y%m%d%H%M%S')  # (예) 20260319143000
file_path = f'{dir}/{file_name}_{suffix}.keras'
print(file_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/lab_ml/best_cnn1_20260918043135.keras

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(filepath=file_path, save_best_only=True)
early_stop_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

# %%
result = cnn_1.fit(x=x_train_scaled, y=y_train, batch_size=64, epochs=1_000,
                   validation_data=[x_test_scaled, y_test],
                   callbacks=[checkpoint_cb, early_stop_cb])
# Out:
# Epoch 1/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.7263 - val_loss: 0.3815 - val_sparse_categorical_accuracy: 0.8616
# Epoch 2/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.4240 - sparse_categorical_accuracy: 0.8582 - val_loss: 0.3273 - val_sparse_categorical_accuracy: 0.8846
# Epoch 3/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.3488 - sparse_categorical_accuracy: 0.8850 - val_loss: 0.2816 - val_sparse_categorical_accuracy: 0.8996
# Epoch 4/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.3042 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.2981 - val_sparse_categorical_accuracy: 0.8998
# Epoch 5/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.2903 - val_sparse_categorical_accuracy: 0.9022
# Epoch 6/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.2467 - sparse_categorical_accuracy: 0.9166 - val_loss: 0.2808 - val_sparse_categorical_accuracy: 0.9098
# Epoch 7/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.2729 - val_sparse_categorical_accuracy: 0.9129
# Epoch 8/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.2087 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.2836 - val_sparse_categorical_accuracy: 0.9129
# Epoch 9/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.1928 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.3055 - val_sparse_categorical_accuracy: 0.9116
# Epoch 10/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.2733 - val_sparse_categorical_accuracy: 0.9132

# %%
def plot_train_val_loss(history):
    # 파라미터 history: fit 메서드 리턴값(History 타입 객체)
    epochs = history.epoch
    history = history.history
    plt.plot(epochs, history['loss'], 'bo-', label='train loss')
    plt.plot(epochs, history['val_loss'], 'ro:', label='validation loss')
    plt.legend()
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()

# %%
plot_train_val_loss(result)

# %% [markdown]
# ## CNN 모델 평가

# %%
# 훈련 셋 평가(손실, 정확도)
cnn_1.evaluate(x=x_train_scaled, y=y_train)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1553 - sparse_categorical_accuracy: 0.9427
# [0.15533486008644104, 0.9426833391189575]

# %%
# 테스트 셋 평가
cnn_1.evaluate(x=x_test_scaled, y=y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2729 - sparse_categorical_accuracy: 0.9129
# [0.2728641927242279, 0.9128999710083008]

# %% [markdown]
# # CNN 연습 2

# %% [markdown]
# *   Keras 패키지의 손글씨 MNIST 예제 데이터셋
#     *   예제 데이터셋의 일부(예: 100개)를 시각화.
#     *   훈련 셋과 테스트 셋의 데이터는 0. ~ 1. 스케일로 스케일링.
# *   CNN 모델 구조
#     *   Conv2D(filters=32, kernel_size=3)
#     *   Conv2D(filters=64, kernel_size=3)
#     *   MaxPool2D
#     *   Flatten
#     *   Dropout(rate=0.25)
#     *   Dense(units=128)
#     *   Dropout(rate=0.5)
#     *   Dense - 출력층
# *   모든 합성곱 층(Conv2D)와 출력층을 제외한 밀집층(Dense)에서
#     *   활성화 함수(`activation`)는 ReLU로 설정.
#     *   커널 초기화 함수(`kernel_initializer`)를 'he_normal'로 설정.
# *   모델의 옵티마이저(`optimizer`)는 Nadam을 사용.
# *   ModelCheckpoint, EarlyStopping 콜백을 함께 사용해서 모델을 훈련을 조기종료 하고, 최적의 모델은 best_cnn2.keras 파일에 저장.
# *   각 에포크에서의 손실 함수를 시각화.
# *   모델의 성능을 평가.

# %% [markdown]
# ## MNIST 데이터셋 준비

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
plot_mnist_image(x_train[:50])

# %%
# 훈련 셋과 테스트 셋의 모양은 (n_samples, height, width, channels), 스케일은 0.0 ~ 1.0으로 변환
x_train_scaled = x_train.reshape((-1, 28, 28, 1)) / 255.0
x_test_scaled = x_test.reshape((-1, 28, 28, 1)) / 255.0

# %% [markdown]
# ## CNN 모델 생성

# %%
keras.utils.set_random_seed(42)

# %%
cnn_2 = keras.Sequential(layers=[
    keras.Input(shape=(28, 28, 1)),
    keras.layers.Conv2D(filters=32, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.Conv2D(filters=64, kernel_size=3, padding='same',
                        activation='relu', kernel_initializer='he_normal'),
    keras.layers.MaxPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dropout(rate=0.25),
    keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'),  # 밀집층
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(units=10, activation='softmax')
])

# %%
cnn_2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │     1,605,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,625,866 (6.20 MB)
#  Trainable params: 1,625,866 (6.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(model=cnn_2, dpi=64, show_shapes=True)

# %% [markdown]
# ## CNN 모델 훈련

# %%
cnn_2.compile(optimizer=keras.optimizers.Nadam(),
              loss=keras.losses.sparse_categorical_crossentropy,
              metrics=[keras.metrics.sparse_categorical_accuracy])

# %%
dir = '/content/drive/MyDrive/Colab Notebooks/lab_da'
file_name = 'best_cnn2'
time_suffix = datetime.now().strftime('%Y%m%d%H%M%S')
file_path = f'{dir}/{file_name}_{time_suffix}.keras'
print(file_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/lab_da/best_cnn2_20260918043400.keras

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(filepath=file_path, save_best_only=True)
early_stop_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

# %%
result = cnn_2.fit(x=x_train_scaled, y=y_train, batch_size=64, epochs=1_000,
                   callbacks=[checkpoint_cb, early_stop_cb],
                   validation_data=[x_test_scaled, y_test])
# Out:
# Epoch 1/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - loss: 0.2038 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.0574 - val_sparse_categorical_accuracy: 0.9806
# Epoch 2/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 0.9859
# Epoch 3/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0633 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0441 - val_sparse_categorical_accuracy: 0.9866
# Epoch 4/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0393 - val_sparse_categorical_accuracy: 0.9875
# Epoch 5/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0360 - val_sparse_categorical_accuracy: 0.9892
# Epoch 6/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0370 - val_sparse_categorical_accuracy: 0.9897
# Epoch 7/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9914
# Epoch 8/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0344 - val_sparse_categorical_accuracy: 0.9905
# Epoch 9/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.0401 - val_sparse_categorical_accuracy: 0.9893
# Epoch 10/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0375 - val_sparse_categorical_accuracy: 0.9896
# Epoch 11/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0343 - val_sparse_categorical_accuracy: 0.9916
# Epoch 12/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0378 - val_sparse_categorical_accuracy: 0.9905
# Epoch 13/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.0337 - val_sparse_categorical_accuracy: 0.9923
# Epoch 14/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.0331 - val_sparse_categorical_accuracy: 0.9919
# Epoch 15/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9922
# Epoch 16/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0379 - val_sparse_categorical_accuracy: 0.9918
# Epoch 17/1000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0355 - val_sparse_categorical_accuracy: 0.9928

# %%
plot_train_val_loss(result)

# %% [markdown]
# ## CNN 모델 평가

# %%
# 훈련 셋 평가
cnn_2.evaluate(x=x_train_scaled, y=y_train)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9996
# [0.0014118864201009274, 0.9995833039283752]

# %%
# 테스트 셋 평가
cnn_2.evaluate(x=x_test, y=y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 19.3775 - sparse_categorical_accuracy: 0.9824
# [19.377527236938477, 0.9824000000953674]
