# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202605_BD57/blob/main/lab_python/python10_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오류(Error)의 종류

# %%
# prnt('Hello, Python!')
#> 위 코드는 실행하면 NameError 발생 -> 문법 오류 -> 문법에 맞게 수정 -> 오류 해결

print('Hello, Python!')
# Out:
# Hello, Python!

# %%
number = int(input('정수 입력>>> '))
print(number)
# Out:
# 정수 입력>>> abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6217/3239371709.py in <cell line: 0>()
# ----> 1 number = int(input('정수 입력>>> '))
#       2 print(number)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# 위 코드 셀은 사용자가 어떤 문자열을 입력했는 지에 따라서 코드 실행이 정상적으로 종료될 수도 있고, 에러가 발생해서 비정상적으로 셀이 종료될 수도 있음.
#
# 문법적인 오류가 아니라 예외적인 상황이 발생할 가능성이 있는 코드들은 예외 처리를 할 수 있음.
