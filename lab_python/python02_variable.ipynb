# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202605_BD57/blob/main/lab_python/python02_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Data Type(자료형)

# %% [markdown]
# * 숫자 타입
#   *  정수: int(integer)
#   *  실수: float(floating-point number)
# * 문자 타입: str(string)
# * 논리 타입: bool(boolean). 참(True)/거짓(False).

# %% [markdown]
# ## 숫자 타입

# %%
# 변수 선언, 값을 할당: 변수_이름 = 값
n = 123
print(n)  # 변수 n에 할당된 값을 출력.
print(type(n))  # 변수 n의 데이터 타입을 출력.
# Out:
# 123
# <class 'int'>

# %%
pi = 3.141592
print(pi)
print(type(pi))
# Out:
# 3.141592
# <class 'float'>

# %% [markdown]
# ## 문자열 타입

# %%
name = '오쌤'
print(name)
print(type(name))
# Out:
# 오쌤
# <class 'str'>

# %% [markdown]
# ## 논리 타입

# %%
b = False  # 파이썬 참/거짓을 표현하는 예약어(식별자): True/False
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>

# %%
b = 1 > 5
print(b)
# Out:
# False

# %% [markdown]
# ## 명시적 타입 변환

# %% [markdown]
# * `int(arg)`: 아규먼트(arg)로 전달된 값을 정수로 변환해서 반환.
#   *  문자열 --> 정수
#   *  실수 --> 정수
# * `float(arg)`: 아규먼트로 전달된 값을 실수로 변환해서 반환.
#   *  문자열 --> 실수
#   *  정수 --> 실수
# * `str(arg)`: 아규먼트로 전달된 값을 문자열로 변환해서 반환.
#   *  정수, 실수, ... --> 문자열

# %%
# input() 함수: 키보드에서 입력한 값들을 문자열로 받아들임.
x = int(input('정수 입력>>> '))  #> 입력값을 정수로 변환해서 변수 x에 저장.
y = int(input('정수 입력>>> '))

print(x - y)
# Out:
# 정수 입력>>> 123
# 정수 입력>>> 100
# 23

# %% [markdown]
# # 연산자(Operator)
