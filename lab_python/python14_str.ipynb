# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202605_BD57/blob/main/lab_python/python14_str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `str` 클래스 메서드

# %%
msg = 'heLLo, pyTHon! hello PYTHON. 안녕하세요?'

# %%
type(msg)
# Out:
# str

# %%
print(msg)  #> str 클래스의 __str__ 메서드가 만들어 주는 문자열
# Out:
# heLLo, pyTHon! hello PYTHON. 안녕하세요?

# %%
msg  #> str 클래스의 __repr__ 메서드가 만들어 주는 문자열
# Out:
# 'heLLo, pyTHon! hello PYTHON. 안녕하세요?'

# %%
result = msg.lower()  # 문자열 msg의 모든 영문자를 소문자로 변환한 "새로운" 문자열을 리턴.
print(result)
print(msg)  #> 원본 문자열은 변경되지 않음.
# Out:
# hello, python! hello python. 안녕하세요?
# heLLo, pyTHon! hello PYTHON. 안녕하세요?

# %%
result = msg.upper()
print(result)  #> 모든 영문자들을 대문자로 변환한 새로운 문자열을 리턴.
print(msg)  #> 원본 문자열은 변경되지 않음.
# Out:
# HELLO, PYTHON! HELLO PYTHON. 안녕하세요?
# heLLo, pyTHon! hello PYTHON. 안녕하세요?

# %%
msg.count('h')
# Out:
# 2

# %%
# 대/소문자 구분없이 'h' 또는 'H'의 개수
msg.lower().count('h')
# Out:
# 4

# %%
msg.find('l')  #> msg에서 'l'이 등장하는 가장 낮은 인덱스.
# Out:
# 17

# %%
msg.find('Q')  #> 찾으려는 문자열이 포함되어 있지 않은 경우에는 -1을 리턴.
# Out:
# -1

# %%
email = 'gildong@naver.com'

# 이메일 아이디(gildong)와 도메인(naver.com)을 각각 찾아서 출력.
idx = email.find('@')
print(idx)

print(email[:idx])  # 문자열에서 인덱스를 사용해서 slicing
print(email[(idx + 1):])
# Out:
# 7
# gildong
# naver.com

# %%
result = msg.split()
#> 공백(space, tab, enter, ...)들을 구분자(separator)로 해서, 잘라진 문자열들의 리스트를 반환.
print(result)
# Out:
# ['heLLo,', 'pyTHon!', 'hello', 'PYTHON.', '안녕하세요?']

# %%
today = '2026-06-26'
result = today.split(sep='-')  #> '-'를 기준으로 문자열들을 자름.
print(result)
# Out:
# ['2026', '06', '26']

# %%
print(email)
print(email.split(sep='@'))
print(email.split(sep='@')[0])
print(email.split(sep='@')[1])
# Out:
# gildong@naver.com
# ['gildong', 'naver.com']
# gildong
# naver.com

# %%
csv = '1,홍길동,100,90,80'  # comma-separated values
csv.split(sep=',')  #> 잘려진 문자열들의 리스트를 반환.
# Out:
# ['1', '홍길동', '100', '90', '80']

# %%
'/'.join(['2026', '06', '26'])
#> '/'를 구분자로 해서 리스트의 문자열들을 하나로 합쳐서 리턴.
# Out:
# '2026/06/26'

# %%
'2026/06/26'.split('/')
# Out:
# ['2026', '06', '26']

# %%
':'.join(['a', 'b', 'c', 'd'])
# Out:
# 'a:b:c:d'

# %%
sentence = '        안녕하세요?       점심 맛있게 드셨나요?       '
print(sentence)
print(sentence.lstrip())
print(sentence.rstrip())
print(sentence.strip())
# Out:
#         안녕하세요?       점심 맛있게 드셨나요?
# 안녕하세요?       점심 맛있게 드셨나요?
#         안녕하세요?       점심 맛있게 드셨나요?
# 안녕하세요?       점심 맛있게 드셨나요?

# %%
s = 'hello python'
s.replace('h', 'H')
# Out:
# 'Hello pytHon'

# %%
s.replace('h', 'H', 1)
# Out:
# 'Hello python'

# %%
s.replace('h', 'H', 2)
# Out:
# 'Hello pytHon'

# %%
sentence = '안녕하세요. 저는 오쌤입니다. 만나서 반갑습니다.'
sentence.replace('.', '').split()
#> 문장에서 구두점을 제거하고 단어들의 리스트를 생성.
# Out:
# ['안녕하세요', '저는', '오쌤입니다', '만나서', '반갑습니다']
